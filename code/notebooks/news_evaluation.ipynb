# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import os
import sys

sys.path.append('..')
from utils.evaluation_utils import evaluate_retrieval_metrics, moral_diversity_by_model, alternative_voices_diversity_by_model, calculate_activation_diversity, perspective_pluralism_by_model, calculate_activation_diversity_reference, moral_diversity_reference, perspective_pluralism_reference, alternative_voices_diversity_reference
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Immigration news evaluation

# %%
topic = 'immigration'

# %%
llm_news = pd.read_csv(f'news/retrieved/step3_{topic}.csv').dropna(subset=['text'])

# %%
llm_news
# Out:
#                                                  title        date  \
# 0    Concerns grow over dire conditions in immigran...  2025-06-30
# 1    Trump likely to visit 'Alligator Alcatraz' mig...  2025-06-30
# 2    Analysis: Trump’s visit to a migrant camp call...  2025-07-01
# 3    Democratic governors spar with US Congress Rep...  2025-06-12
# 4    The Human Cost of the Trump Administration’s I...  2025-05-19
# ..                                                 ...         ...
# 158  ICE Agents Chase After Farmworkers as They Fle...  2025-06-13
# 159  Immigrants abandon Dems to support GOP immigra...  2025-06-13
# 160            Americas Migration Brief - June 9, 2025  2025-06-09
# 161  ICE Arrests Teenager Eating Lunch Weeks After ...  2025-06-12
# 162  The Human Cost of the Trump Administration’s I...  2025-05-19
#
#                    source                                                url  \
# 0         lasvegassun.com  https://lasvegassun.com/news/2025/jun/30/conce...
# 1            thehindu.com  https://www.thehindu.com/news/international/tr...
# 2                 cnn.com  https://edition.cnn.com/2025/07/01/politics/al...
# 3             reuters.com  https://www.reuters.com/world/us/democratic-go...
# 4    humanrightsfirst.org  https://humanrightsfirst.org/library/the-human...
# ..                    ...                                                ...
# 158           Ground News  https://ground.news/article/ice-expands-immigr...
# 159               foxnews  https://www.foxnews.com/politics/immigrants-ab...
# 160       Migration Brief  https://www.migrationbrief.com/p/americas-migr...
# 161              Newsweek  https://www.newsweek.com/ice-arrests-teenager-...
# 162    Human Rights First  https://humanrightsfirst.org/library/the-human...
#
#              model                                               text
# 0           gpt-4o  Far from public view, the toll of the Trump ad...
# 1           gpt-4o  U.S. President Donald Trump is expected to att...
# 2           gpt-4o  The name alone surely was enough to lure Donal...
# 3           gpt-4o  WASHINGTON, June 12 (Reuters) - Democratic gov...
# 4           gpt-4o  by Ellie Conover, Communications Intern\n\nThi...
# ..             ...                                                ...
# 158  qwen3-30b-a3b  Faced with the raids of the immigration police...
# 159  qwen3-30b-a3b  It appears that the group of American voters w...
# 160  qwen3-30b-a3b  “President Trump’s new travel ban appears devi...
# 161  qwen3-30b-a3b  Federal immigration agents allegedly arrested ...
# 162  qwen3-30b-a3b  by Ellie Conover, Communications Intern\n\nThi...
#
# [163 rows x 6 columns]

# %% [markdown]
# ### Retrieval metrics

# %%
retrieval_metrics = evaluate_retrieval_metrics(
    llm_news,
    experiment_date='2025-07-01',
    window_days=30,
    num_articles=10
)

# %%
retrieval_metrics
# Out:
#                      model  num_articles_retrieved  valid_url_rate  \
# 0                   gpt-4o                       9             0.9
# 1              gpt-4o-mini                      10             1.0
# 2                  gpt-4-1                      10             1.0
# 3             gpt-4-1-mini                      10             1.0
# 4        claude-3.7-sonnet                      10             1.0
# 5          claude-sonnet-4                      10             1.0
# 6         gemini-2.5-flash                      10             1.0
# 7           gemini-2.5-pro                      10             1.0
# 8         deepseek-r1-0528                      10             1.0
# 9    deepseek-chat-v3-0324                       8             0.8
# 10    magistral-small-2506                       8             0.8
# 11   magistral-medium-2506                      10             1.0
# 12  llama-3.3-70b-instruct                       9             0.9
# 13        llama-4-maverick                      10             1.0
# 14           llama-4-scout                       9             0.9
# 15               qwen3-14b                      10             1.0
# 16           qwen3-30b-a3b                      10             1.0
#
#     temporal_compliance_rate  source_variety
# 0                        0.8               9
# 1                        0.7               8
# 2                        0.7               7
# 3                        0.9               9
# 4                        0.8               8
# 5                        0.9               9
# 6                        0.7               7
# 7                        1.0               7
# 8                        0.9               9
# 9                        0.6               5
# 10                       0.5               8
# 11                       0.7               8
# 12                       0.7               5
# 13                       0.7               7
# 14                       0.6               6
# 15                       0.9               8
# 16                       0.9               7

# %% [markdown]
# we used the following code to correct some dates:
#
# mask = llm_news['url'] == 'https://www.newsweek.com/ice-arrests-teenager-lunch-weeks-graduation-2084615'
#
# correct_date = llm_news.loc[mask, 'date'].dropna().iloc[0]
#
# llm_news.loc[mask, 'date'] = correct_date

# %% [markdown]
# ### Diversity metrics

# %%
reference_news = pd.read_csv(f'news/reference/{topic}_news.csv')
reference_news = reference_news[~reference_news['article_text'].str.contains('This may take a few second', na=False)].reset_index()

# %%
reference_news
# Out:
#     index                                              title  \
# 0       0  From San Diego to the Bay Area, California res...
# 1       1  The Immigration Court System, Explained - Bren...
# 2       2  New Immigration Policies Will Increase Prices ...
# 3       3  Restricting The Entry of Foreign Nationals to ...
# 4       4  From Day One, Trump's Immigration Agenda Has G...
# ..    ...                                                ...
# 76     84  Immigration Raids Add to Absence Crisis for Sc...
# 77     85  Catholic Bishops Oppose Trump’s Immigration Ef...
# 78     86  Here's where to get help if you're affected by...
# 79     87  The Trump administration is making an unpreced...
# 80     88  This beloved Mexican market in LA is losing bu...
#
#                              date  \
# 0   Thu, 19 Jun 2025 07:00:00 GMT
# 1   Tue, 24 Jun 2025 18:13:48 GMT
# 2   Wed, 25 Jun 2025 16:17:12 GMT
# 3   Wed, 04 Jun 2025 07:00:00 GMT
# 4   Fri, 06 Jun 2025 07:00:00 GMT
# ..                            ...
# 76  Mon, 16 Jun 2025 07:00:00 GMT
# 77  Sun, 29 Jun 2025 09:00:55 GMT
# 78  Mon, 23 Jun 2025 12:00:00 GMT
# 79  Tue, 24 Jun 2025 09:00:00 GMT
# 80  Fri, 20 Jun 2025 07:00:00 GMT
#
#                                                   url  \
# 0   https://calmatters.org/economy/2025/06/califor...
# 1   https://www.brennancenter.org/our-work/researc...
# 2   https://www.fwd.us/news/new-immigration-polici...
# 3   https://www.whitehouse.gov/presidential-action...
# 4   https://www.aclu.org/news/immigrants-rights/fr...
# ..                                                ...
# 76  https://www.nytimes.com/2025/06/16/us/immigrat...
# 77  https://www.nytimes.com/2025/06/29/us/catholic...
# 78  https://laist.com/news/politics/resource-guide...
# 79  https://www.npr.org/2025/06/24/nx-s1-5423604/t...
# 80  https://www.npr.org/2025/06/20/nx-s1-5434354/t...
#
#                            source  \
# 0          https://calmatters.org
# 1   https://www.brennancenter.org
# 2              https://www.fwd.us
# 3      https://www.whitehouse.gov
# 4            https://www.aclu.org
# ..                            ...
# 76        https://www.nytimes.com
# 77        https://www.nytimes.com
# 78              https://laist.com
# 79            https://www.npr.org
# 80            https://www.npr.org
#
#                                          article_text
# 0   Brandon Mejia usually spends his weekends cond...
# 1   View the entire Explainers collection\n\nImmig...
# 2   We built a multisector, general equilibrium mo...
# 3   BY THE PRESIDENT OF THE UNITED STATES OF AMERI...
# 4   Four months into President Donald Trump’s seco...
# ..                                                ...
# 76  As President Trump promised mass deportations,...
# 77  As the Trump administration escalates its aggr...
# 78  Only 7% of LAist readers currently donate to f...
# 79  The Trump administration's push to rapidly ama...
# 80  In the heart of east Los Angeles stands a belo...
#
# [81 rows x 6 columns]

# %%
activation_df = calculate_activation_diversity_reference(reference_news, num_articles=10, n_subsets=10)
perspective_df = perspective_pluralism_reference(reference_news, threshold=85, num_articles=10, n_subsets=10)
alternative_voices_df = alternative_voices_diversity_reference(reference_news, threshold=80, num_articles=10, n_subsets=10)
moral_diversity_df = moral_diversity_reference(reference_news, metric='cosine', num_articles=10, n_subsets=10)

# %%
llm_news
# Out:
#                                                  title        date  \
# 0    Concerns grow over dire conditions in immigran...  2025-06-30
# 1    Trump likely to visit 'Alligator Alcatraz' mig...  2025-06-30
# 2    Analysis: Trump’s visit to a migrant camp call...  2025-07-01
# 3    Democratic governors spar with US Congress Rep...  2025-06-12
# 4    The Human Cost of the Trump Administration’s I...  2025-05-19
# ..                                                 ...         ...
# 158  ICE Agents Chase After Farmworkers as They Fle...  2025-06-13
# 159  Immigrants abandon Dems to support GOP immigra...  2025-06-13
# 160            Americas Migration Brief - June 9, 2025  2025-06-09
# 161  ICE Arrests Teenager Eating Lunch Weeks After ...  2025-06-12
# 162  The Human Cost of the Trump Administration’s I...  2025-05-19
#
#                    source                                                url  \
# 0         lasvegassun.com  https://lasvegassun.com/news/2025/jun/30/conce...
# 1            thehindu.com  https://www.thehindu.com/news/international/tr...
# 2                 cnn.com  https://edition.cnn.com/2025/07/01/politics/al...
# 3             reuters.com  https://www.reuters.com/world/us/democratic-go...
# 4    humanrightsfirst.org  https://humanrightsfirst.org/library/the-human...
# ..                    ...                                                ...
# 158           Ground News  https://ground.news/article/ice-expands-immigr...
# 159               foxnews  https://www.foxnews.com/politics/immigrants-ab...
# 160       Migration Brief  https://www.migrationbrief.com/p/americas-migr...
# 161              Newsweek  https://www.newsweek.com/ice-arrests-teenager-...
# 162    Human Rights First  https://humanrightsfirst.org/library/the-human...
#
#              model                                               text
# 0           gpt-4o  Far from public view, the toll of the Trump ad...
# 1           gpt-4o  U.S. President Donald Trump is expected to att...
# 2           gpt-4o  The name alone surely was enough to lure Donal...
# 3           gpt-4o  WASHINGTON, June 12 (Reuters) - Democratic gov...
# 4           gpt-4o  by Ellie Conover, Communications Intern\n\nThi...
# ..             ...                                                ...
# 158  qwen3-30b-a3b  Faced with the raids of the immigration police...
# 159  qwen3-30b-a3b  It appears that the group of American voters w...
# 160  qwen3-30b-a3b  “President Trump’s new travel ban appears devi...
# 161  qwen3-30b-a3b  Federal immigration agents allegedly arrested ...
# 162  qwen3-30b-a3b  by Ellie Conover, Communications Intern\n\nThi...
#
# [163 rows x 6 columns]

# %% [markdown]
# #### Morality

# %%
moral_metrics = moral_diversity_by_model(llm_news, reference_news)
# Out:
# /home/sergio/.virtualenvs/llm-news/lib/python3.10/site-packages/spacy/pipeline/lemmatizer.py:188: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# /home/sergio/.virtualenvs/llm-news/lib/python3.10/site-packages/spacy/pipeline/lemmatizer.py:188: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# ### Alternative voices

# %%
alternativevoice_metrics = alternative_voices_diversity_by_model(llm_news, reference_news)

# %% [markdown]
# ### Activation

# %%
activation_metrics = calculate_activation_diversity(llm_news, reference_news)

# %% [markdown]
# ### Representation

# %%
representation_metrics = perspective_pluralism_by_model(llm_news, reference_news)

# %% [markdown]
# ## Visualization

# %%
retrieval_metrics
# Out:
#                      model  num_articles_retrieved  valid_url_rate  \
# 0                   gpt-4o                       9             0.9
# 1              gpt-4o-mini                      10             1.0
# 2                  gpt-4-1                      10             1.0
# 3             gpt-4-1-mini                      10             1.0
# 4        claude-3.7-sonnet                      10             1.0
# 5          claude-sonnet-4                      10             1.0
# 6         gemini-2.5-flash                      10             1.0
# 7           gemini-2.5-pro                      10             1.0
# 8         deepseek-r1-0528                      10             1.0
# 9    deepseek-chat-v3-0324                       8             0.8
# 10    magistral-small-2506                       8             0.8
# 11   magistral-medium-2506                      10             1.0
# 12  llama-3.3-70b-instruct                       9             0.9
# 13        llama-4-maverick                      10             1.0
# 14           llama-4-scout                       9             0.9
# 15               qwen3-14b                      10             1.0
# 16           qwen3-30b-a3b                      10             1.0
#
#     temporal_compliance_rate  source_variety
# 0                        0.8               9
# 1                        0.7               8
# 2                        0.7               7
# 3                        0.9               9
# 4                        0.8               8
# 5                        0.9               9
# 6                        0.7               7
# 7                        1.0               7
# 8                        0.9               9
# 9                        0.6               5
# 10                       0.5               8
# 11                       0.7               8
# 12                       0.7               5
# 13                       0.7               7
# 14                       0.6               6
# 15                       0.9               8
# 16                       0.9               7

# %%
retrieval_metrics.to_latex()
# Out:
# '\\begin{tabular}{llrrrr}\n\\toprule\n & model & num_articles_retrieved & valid_url_rate & temporal_compliance_rate & source_variety \\\\\n\\midrule\n0 & gpt-4o & 9 & 0.900000 & 0.800000 & 9 \\\\\n1 & gpt-4o-mini & 10 & 1.000000 & 0.700000 & 8 \\\\\n2 & gpt-4-1 & 10 & 1.000000 & 0.700000 & 7 \\\\\n3 & gpt-4-1-mini & 10 & 1.000000 & 0.900000 & 9 \\\\\n4 & claude-3.7-sonnet & 10 & 1.000000 & 0.800000 & 8 \\\\\n5 & claude-sonnet-4 & 10 & 1.000000 & 0.900000 & 9 \\\\\n6 & gemini-2.5-flash & 10 & 1.000000 & 0.700000 & 7 \\\\\n7 & gemini-2.5-pro & 10 & 1.000000 & 1.000000 & 7 \\\\\n8 & deepseek-r1-0528 & 10 & 1.000000 & 0.900000 & 9 \\\\\n9 & deepseek-chat-v3-0324 & 8 & 0.800000 & 0.600000 & 5 \\\\\n10 & magistral-small-2506 & 8 & 0.800000 & 0.500000 & 8 \\\\\n11 & magistral-medium-2506 & 10 & 1.000000 & 0.700000 & 8 \\\\\n12 & llama-3.3-70b-instruct & 9 & 0.900000 & 0.700000 & 5 \\\\\n13 & llama-4-maverick & 10 & 1.000000 & 0.700000 & 7 \\\\\n14 & llama-4-scout & 9 & 0.900000 & 0.600000 & 6 \\\\\n15 & qwen3-14b & 10 & 1.000000 & 0.900000 & 8 \\\\\n16 & qwen3-30b-a3b & 10 & 1.000000 & 0.900000 & 7 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
moral_metrics
# Out:
#                      model  diversity  diversity_ref
# 0                   gpt-4o   0.222389       0.105427
# 1              gpt-4o-mini   0.186818       0.105427
# 2                  gpt-4-1   0.178064       0.105427
# 3             gpt-4-1-mini   0.277225       0.105427
# 4        claude-3.7-sonnet   0.168737       0.105427
# 5          claude-sonnet-4   0.251688       0.105427
# 6         gemini-2.5-flash   0.204333       0.105427
# 7           gemini-2.5-pro   0.208141       0.105427
# 8         deepseek-r1-0528   0.274044       0.105427
# 9    deepseek-chat-v3-0324   0.181140       0.105427
# 10    magistral-small-2506   0.271875       0.105427
# 11   magistral-medium-2506   0.229084       0.105427
# 12  llama-3.3-70b-instruct   0.160781       0.105427
# 13        llama-4-maverick   0.203595       0.105427
# 14           llama-4-scout   0.190888       0.105427
# 15               qwen3-14b   0.266767       0.105427
# 16           qwen3-30b-a3b   0.233512       0.105427

# %%
alternativevoice_metrics
# Out:
#                      model  voice_diversity  voice_diversity_ref
# 0                   gpt-4o         0.456747             0.433884
# 1              gpt-4o-mini         0.480000             0.433884
# 2                  gpt-4-1         0.486993             0.433884
# 3             gpt-4-1-mini         0.484429             0.433884
# 4        claude-3.7-sonnet         0.500000             0.433884
# 5          claude-sonnet-4         0.484429             0.433884
# 6         gemini-2.5-flash         0.500000             0.433884
# 7           gemini-2.5-pro         0.499200             0.433884
# 8         deepseek-r1-0528         0.484429             0.433884
# 9    deepseek-chat-v3-0324         0.468750             0.433884
# 10    magistral-small-2506         0.489796             0.433884
# 11   magistral-medium-2506         0.497449             0.433884
# 12  llama-3.3-70b-instruct         0.500000             0.433884
# 13        llama-4-maverick         0.497449             0.433884
# 14           llama-4-scout         0.500000             0.433884
# 15               qwen3-14b         0.498270             0.433884
# 16           qwen3-30b-a3b         0.493827             0.433884

# %%
representation_metrics
# Out:
#                      model  mean_perspectives  std_perspectives  \
# 0                   gpt-4o           7.555556          4.474896
# 1              gpt-4o-mini           8.800000          3.600000
# 2                  gpt-4-1           8.700000          3.634556
# 3             gpt-4-1-mini           6.900000          4.570558
# 4        claude-3.7-sonnet           8.100000          4.158125
# 5          claude-sonnet-4           7.200000          4.664762
# 6         gemini-2.5-flash           8.700000          4.001250
# 7           gemini-2.5-pro           8.000000          4.857983
# 8         deepseek-r1-0528           7.000000          4.626013
# 9    deepseek-chat-v3-0324           9.125000          3.407253
# 10    magistral-small-2506           7.375000          3.838538
# 11   magistral-medium-2506           8.000000          4.098780
# 12  llama-3.3-70b-instruct           8.444444          3.624335
# 13        llama-4-maverick           8.600000          3.903844
# 14           llama-4-scout           8.555556          4.112612
# 15               qwen3-14b           6.400000          4.586938
# 16           qwen3-30b-a3b           7.900000          4.036087
#
#     mean_perspectives_ref  std_perspectives_ref
# 0                     6.0               3.49285
# 1                     6.0               3.49285
# 2                     6.0               3.49285
# 3                     6.0               3.49285
# 4                     6.0               3.49285
# 5                     6.0               3.49285
# 6                     6.0               3.49285
# 7                     6.0               3.49285
# 8                     6.0               3.49285
# 9                     6.0               3.49285
# 10                    6.0               3.49285
# 11                    6.0               3.49285
# 12                    6.0               3.49285
# 13                    6.0               3.49285
# 14                    6.0               3.49285
# 15                    6.0               3.49285
# 16                    6.0               3.49285

# %%
activation_metrics
# Out:
#                      model  activation_diversity  activation_diversity_ref  \
# 0                   gpt-4o              0.045968                  0.042848
# 1              gpt-4o-mini              0.039502                  0.042848
# 2                  gpt-4-1              0.040603                  0.042848
# 3             gpt-4-1-mini              0.038183                  0.042848
# 4        claude-3.7-sonnet              0.021415                  0.042848
# 5          claude-sonnet-4              0.035626                  0.042848
# 6         gemini-2.5-flash              0.033088                  0.042848
# 7           gemini-2.5-pro              0.030364                  0.042848
# 8         deepseek-r1-0528              0.026320                  0.042848
# 9    deepseek-chat-v3-0324              0.042934                  0.042848
# 10    magistral-small-2506              0.040153                  0.042848
# 11   magistral-medium-2506              0.035474                  0.042848
# 12  llama-3.3-70b-instruct              0.034566                  0.042848
# 13        llama-4-maverick              0.033769                  0.042848
# 14           llama-4-scout              0.024325                  0.042848
# 15               qwen3-14b              0.042876                  0.042848
# 16           qwen3-30b-a3b              0.035624                  0.042848
#
#     mean_activation  mean_activation_ref
# 0          0.065231             0.057838
# 1          0.058236             0.057838
# 2          0.056617             0.057838
# 3          0.055811             0.057838
# 4          0.034253             0.057838
# 5          0.059397             0.057838
# 6          0.054714             0.057838
# 7          0.050165             0.057838
# 8          0.046851             0.057838
# 9          0.059226             0.057838
# 10         0.061772             0.057838
# 11         0.056007             0.057838
# 12         0.054483             0.057838
# 13         0.052057             0.057838
# 14         0.049523             0.057838
# 15         0.092022             0.057838
# 16         0.072511             0.057838

# %%
from functools import reduce

dfs = [activation_metrics[['model', 'activation_diversity']], alternativevoice_metrics[['model', 'voice_diversity']], representation_metrics[['model', 'mean_perspectives']], moral_metrics[['diversity_ref']]]
df_final = reduce(lambda left, right: pd.merge(left, right, on='model', how='inner'), dfs)

# %%
df_final.columns = ['model_name', 'activation', 'alternative_voices', 'representation', 'moral_diversity']

# %%
df_final
# Out:
#                 model_name  activation  alternative_voices  representation  \
# 0                   gpt-4o    0.045968            0.456747        7.555556
# 1              gpt-4o-mini    0.039502            0.480000        8.800000
# 2                  gpt-4-1    0.040603            0.486993        8.700000
# 3             gpt-4-1-mini    0.038183            0.484429        6.900000
# 4        claude-3.7-sonnet    0.021415            0.500000        8.100000
# 5          claude-sonnet-4    0.035626            0.484429        7.200000
# 6         gemini-2.5-flash    0.033088            0.500000        8.700000
# 7           gemini-2.5-pro    0.030364            0.499200        8.000000
# 8         deepseek-r1-0528    0.026320            0.484429        7.000000
# 9    deepseek-chat-v3-0324    0.042934            0.468750        9.125000
# 10    magistral-small-2506    0.040153            0.489796        7.375000
# 11   magistral-medium-2506    0.035474            0.497449        8.000000
# 12  llama-3.3-70b-instruct    0.034566            0.500000        8.444444
# 13        llama-4-maverick    0.033769            0.497449        8.600000
# 14           llama-4-scout    0.024325            0.500000        8.555556
# 15               qwen3-14b    0.042876            0.498270        6.400000
# 16           qwen3-30b-a3b    0.035624            0.493827        7.900000
#
#     moral_diversity
# 0          0.222389
# 1          0.186818
# 2          0.178064
# 3          0.277225
# 4          0.168737
# 5          0.251688
# 6          0.204333
# 7          0.208141
# 8          0.274044
# 9          0.181140
# 10         0.271875
# 11         0.229084
# 12         0.160781
# 13         0.203595
# 14         0.190888
# 15         0.266767
# 16         0.233512

# %%
df_final.to_latex()
# Out:
# '\\begin{tabular}{llrrrr}\n\\toprule\n & model_name & activation & alternative_voices & representation & moral_diversity \\\\\n\\midrule\n0 & gpt-4o & 0.045968 & 0.456747 & 7.555556 & 0.222389 \\\\\n1 & gpt-4o-mini & 0.039502 & 0.480000 & 8.800000 & 0.186818 \\\\\n2 & gpt-4-1 & 0.040603 & 0.486993 & 8.700000 & 0.178064 \\\\\n3 & gpt-4-1-mini & 0.038183 & 0.484429 & 6.900000 & 0.277225 \\\\\n4 & claude-3.7-sonnet & 0.021415 & 0.500000 & 8.100000 & 0.168737 \\\\\n5 & claude-sonnet-4 & 0.035626 & 0.484429 & 7.200000 & 0.251688 \\\\\n6 & gemini-2.5-flash & 0.033088 & 0.500000 & 8.700000 & 0.204333 \\\\\n7 & gemini-2.5-pro & 0.030364 & 0.499200 & 8.000000 & 0.208141 \\\\\n8 & deepseek-r1-0528 & 0.026320 & 0.484429 & 7.000000 & 0.274044 \\\\\n9 & deepseek-chat-v3-0324 & 0.042934 & 0.468750 & 9.125000 & 0.181140 \\\\\n10 & magistral-small-2506 & 0.040153 & 0.489796 & 7.375000 & 0.271875 \\\\\n11 & magistral-medium-2506 & 0.035474 & 0.497449 & 8.000000 & 0.229084 \\\\\n12 & llama-3.3-70b-instruct & 0.034566 & 0.500000 & 8.444444 & 0.160781 \\\\\n13 & llama-4-maverick & 0.033769 & 0.497449 & 8.600000 & 0.203595 \\\\\n14 & llama-4-scout & 0.024325 & 0.500000 & 8.555556 & 0.190888 \\\\\n15 & qwen3-14b & 0.042876 & 0.498270 & 6.400000 & 0.266767 \\\\\n16 & qwen3-30b-a3b & 0.035624 & 0.493827 & 7.900000 & 0.233512 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
# Calcula la media y la desviación estándar para cada métrica
summary = {
    'Activation Diversity': [activation_df['activation_diversity'].mean(), activation_df['activation_diversity'].std(ddof=0)],
    'Perspective Pluralism': [perspective_df['mean_perspectives'].mean(), perspective_df['mean_perspectives'].std(ddof=0)],
    'Alternative Voices Diversity': [alternative_voices_df['voice_diversity'].mean(), alternative_voices_df['voice_diversity'].std(ddof=0)],
    'Moral Diversity': [moral_diversity_df['moral_diversity'].mean(), moral_diversity_df['moral_diversity'].std(ddof=0)]
}

# Construye la tabla resumen
summary_df = pd.DataFrame(summary, index=['Mean', 'Std'])
# Out:
# /home/sergio/.virtualenvs/llm-news/lib/python3.10/site-packages/spacy/pipeline/lemmatizer.py:188: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
summary_df
# Out:
#       Activation Diversity  Perspective Pluralism  \
# Mean              0.038863               6.990000
# Std               0.017062               0.665507
#
#       Alternative Voices Diversity  Moral Diversity
# Mean                      0.343452         0.130624
# Std                       0.069292         0.032570

# %%
# Calculate mean and std for each metric
summary = {
    'Activation Diversity': [df_final['activation'].mean(), df_final['activation'].std(ddof=0)],
    'Alternative Voices Diversity': [df_final['alternative_voices'].mean(), df_final['alternative_voices'].std(ddof=0)],
    'Perspective Pluralism': [df_final['representation'].mean(), df_final['representation'].std(ddof=0)],
    'Moral Diversity': [df_final['moral_diversity'].mean(), df_final['moral_diversity'].std(ddof=0)]
}

llm_summary_df = pd.DataFrame(summary, index=['Mean', 'Std'])

# %%
llm_summary_df
# Out:
#       Activation Diversity  Alternative Voices Diversity  \
# Mean              0.035341                      0.489516
# Std               0.006568                      0.011966
#
#       Perspective Pluralism  Moral Diversity
# Mean               7.962092         0.218181
# Std                0.757143         0.037807
